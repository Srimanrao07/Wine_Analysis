# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sna
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN

# %%
import sweetviz
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv(r"C:\Users\srima\OneDrive\Desktop\BRO\360digi\DBSCAN\wine_data.csv",encoding = "latin-1")

# %%
df.head()
# Out:
#    OD_read  Proline
# 0     3.92   1065.0
# 1     3.40   1050.0
# 2     3.17   1185.0
# 3     3.45   1480.0
# 4     2.93    735.0

# %%
df.shape
# Out:
# (178, 2)

# %%
df.describe()
# Out:
#           OD_read      Proline
# count  178.000000   178.000000
# mean     2.611685   746.893258
# std      0.709990   314.907474
# min      1.270000   278.000000
# 25%      1.937500   500.500000
# 50%      2.780000   673.500000
# 75%      3.170000   985.000000
# max      4.000000  1680.000000

# %%
my_report = sweetviz.analyze([df,"df"])
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
my_report.show_html("Report.html")
# Out:
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz import AutoViz_Class

# %%
Av = AutoViz_Class()
# %matplotlib inline  
dfte = Av.AutoViz(df, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
               chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Out:
# Shape of your Data Set loaded: (178, 2)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     2 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df1 =df.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (178, 2)

# %%
df1.shape
# Out:
# (177, 2)

# %%
df1.plot(kind = "box", subplots = True, sharey= False , figsize = (10,6))
# Out:
# OD_read        Axes(0.08,0.07;0.395455x0.81)
# Proline    Axes(0.554545,0.07;0.395455x0.81)
# dtype: object
